# %%
import sys
# !conda install --yes --prefix {sys.prefix} psycopg2
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/mikhail/anaconda3
#
#   added / updated specs:
#     - psycopg2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.11.1              |   py39h06a4308_4         927 KB
#     psycopg2-2.9.3             |   py39h37d81fd_0         171 KB
#     ruamel.yaml-0.17.21        |   py39h5eee18b_0         178 KB
#     ruamel.yaml.clib-0.2.6     |   py39h5eee18b_1         140 KB
#     ------------------------------------------------------------
#                                            Total:         1.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   psycopg2           pkgs/main/linux-64::psycopg2-2.9.3-py39h37d81fd_0 None
#   ruamel.yaml        pkgs/main/linux-64::ruamel.yaml-0.17.21-py39h5eee18b_0 None
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
# !pip install pyarrow

# %%
import pyarrow

# %%
df = pd.read_csv('green_tripdata_2019-01.csv', nrows=100)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df.to_sql(name='yellow_data_taxi',con=engine, if_exists='append')
# Out:
# 100

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52                3
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45                2
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22                2
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37                2
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44                5
#
# ...

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 4.17 s, sys: 130 ms, total: 4.3 s
# Wall time: 9.09 s
# 1000

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk, took 9.161 second
# inserted another chunk, took 9.016 second
# inserted another chunk, took 9.007 second
# inserted another chunk, took 9.057 second
# inserted another chunk, took 9.188 second
# inserted another chunk, took 9.205 second
# inserted another chunk, took 9.116 second
# inserted another chunk, took 9.074 second
# inserted another chunk, took 9.093 second
# inserted another chunk, took 9.259 second
# inserted another chunk, took 9.115 second
# /tmp/ipykernel_2695/2113580993.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk, took 9.418 second
# inserted another chunk, took 5.786 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_2695/2113580993.py in <module>
#       2     t_start = time()
#       3
# ...

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2023-01-17 19:17:11--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.80.62, 52.216.40.64, 52.217.169.184, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.80.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi+_zone_lookup.csv.1’
#
# taxi+_zone_lookup.c 100%[===================>]  12.03K  --.-KB/s    in 0s
#
# 2023-01-17 19:17:12 (83.8 MB/s) - ‘taxi+_zone_lookup.csv.1’ saved [12322/12322]

# %%
df_zones = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265

# %%
df_full.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df = pd.read_csv('green_tripdata_2019-01.csv')

df.ltpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
# Out:
# /tmp/ipykernel_4479/2843409908.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.ltpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# ...

# %%
df_full_task3 = df.loc[(df.lpep_pickup_datetime >'2019-01-15 00:00:00') & (df.lpep_pickup_datetime <'2019-01-16 00:00:00')]

df_full_task3_f = df_full_task3.loc[(df_full_task3.lpep_dropoff_datetime >'2019-01-15 00:00:00') & (df_full_task3.lpep_dropoff_datetime <'2019-01-16 00:00:00')]

# %%
df_full_task3
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 272684         2  2019-01-15 15:33:43   2019-01-15 15:33:50
# 275421         2  2019-01-15 16:50:12   2019-01-15 17:23:03
# 276753         2  2019-01-15 17:44:00   2019-01-15 18:03:10
# 278806         2  2019-01-15 20:02:24   2019-01-15 20:17:52
# 279998         2  2019-01-15 00:00:45   2019-01-15 00:07:05
# ...          ...                  ...                   ...
# 301223         2  2019-01-15 22:29:47   2019-01-15 22:39:48
# 301247         2  2019-01-15 23:59:16   2019-01-16 00:05:11
# 301258         2  2019-01-15 22:56:18   2019-01-15 23:43:35
# 301411         2  2019-01-15 22:18:09   2019-01-15 22:25:53
# 301517         2  2019-01-15 21:52:54   2019-01-15 21:55:14
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 272684                  N           5           195           195
# 275421                  N           1           195            17
# ...

# %%
df_full_task3.drop_duplicates()
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 272684         2  2019-01-15 15:33:43   2019-01-15 15:33:50
# 275421         2  2019-01-15 16:50:12   2019-01-15 17:23:03
# 276753         2  2019-01-15 17:44:00   2019-01-15 18:03:10
# 278806         2  2019-01-15 20:02:24   2019-01-15 20:17:52
# 279998         2  2019-01-15 00:00:45   2019-01-15 00:07:05
# ...          ...                  ...                   ...
# 301223         2  2019-01-15 22:29:47   2019-01-15 22:39:48
# 301247         2  2019-01-15 23:59:16   2019-01-16 00:05:11
# 301258         2  2019-01-15 22:56:18   2019-01-15 23:43:35
# 301411         2  2019-01-15 22:18:09   2019-01-15 22:25:53
# 301517         2  2019-01-15 21:52:54   2019-01-15 21:55:14
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 272684                  N           5           195           195
# 275421                  N           1           195            17
# ...

# %%
df_full_task3 = df_full.loc[(df_full.tpep_pickup_datetime >'2021-01-15 00:00:00') & (df_full.tpep_pickup_datetime <'2021-01-16 00:00:00')]

# %%
df1 = df.loc[(df.lpep_pickup_datetime >'2019-01-18 00:00:00') & (df.lpep_pickup_datetime <'2019-01-19 00:00:00')]
df1['trip_distance'].max()
# Out:
# 80.96

# %%
df1 = df.loc[(df.lpep_pickup_datetime >'2019-01-28 00:00:00') & (df.lpep_pickup_datetime <'2019-01-29 00:00:00')]
df1['trip_distance'].max()
# Out:
# 64.27

# %%
df1 = df.loc[(df.lpep_pickup_datetime >'2019-01-15 00:00:00') & (df.lpep_pickup_datetime <'2019-01-16 00:00:00')]
df1['trip_distance'].max()
# Out:
# 117.99

# %%
df1 = df.loc[(df.lpep_pickup_datetime >'2019-01-10 00:00:00') & (df.lpep_pickup_datetime <'2019-01-11 00:00:00')]
df1['trip_distance'].max()
# Out:
# 64.2

# %%
df_full_task5 = df.loc[(df.lpep_pickup_datetime >'2019-01-01 00:00:00') & (df.lpep_pickup_datetime <'2019-01-02 00:00:00')]

#df_full_task5_f = df_full_task5.loc[(df_full_task5.lpep_dropoff_datetime >'2019-01-01 00:00:00') & (df_full_task5.lpep_dropoff_datetime <'2019-01-02 00:00:00')]

#df_full_task5_f.loc[(df_full_task5_f['passenger_count']==2)& (df_full_task5_f['passenger_count']==3)]

df_full_task5.loc[(df_full_task5['passenger_count']==2) ]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 11            2  2019-01-01 00:13:48   2019-01-01 00:21:00                  N
# 32            2  2019-01-01 00:40:23   2019-01-01 00:56:12                  N
# ...         ...                  ...                   ...                ...
# 14971         2  2019-01-01 23:33:40   2019-01-01 23:56:47                  N
# 14996         2  2019-01-01 23:10:16   2019-01-01 23:18:13                  N
# 14997         2  2019-01-01 23:34:15   2019-01-01 23:44:05                  N
# 15029         1  2019-01-01 23:08:14   2019-01-01 23:12:59                  N
# 15032         1  2019-01-01 23:42:48   2019-01-01 23:47:44                  N
#
# ...

# %%
df_full_task5.loc[(df_full_task5['passenger_count']==3) ]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 31            2  2019-01-01 00:08:07   2019-01-01 00:18:36                  N
# 40            2  2019-01-01 00:31:28   2019-01-01 00:57:27                  N
# 67            2  2019-01-01 00:39:51   2019-01-01 00:43:05                  N
# 149           2  2019-01-01 00:35:40   2019-01-01 01:20:13                  N
# 185           2  2019-01-01 00:09:09   2019-01-01 01:04:26                  N
# ...         ...                  ...                   ...                ...
# 14666         1  2019-01-01 22:15:36   2019-01-01 22:28:07                  N
# 14753         1  2019-01-01 23:46:40   2019-01-01 23:53:04                  N
# 14830         2  2019-01-01 23:20:47   2019-01-01 23:28:04                  N
# 14959         2  2019-01-01 23:16:50   2019-01-01 23:24:38                  N
# 14970         2  2019-01-01 23:34:57   2019-01-01 23:45:51                  N
#
# ...

# %%
df_full_task5.loc[(df_full_task5['passenger_count']==3) & (df_full_task5['lpep_dropoff_datetime']<'2019-01-02 00:00:00')]
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 31            2  2019-01-01 00:08:07   2019-01-01 00:18:36                  N
# 40            2  2019-01-01 00:31:28   2019-01-01 00:57:27                  N
# 67            2  2019-01-01 00:39:51   2019-01-01 00:43:05                  N
# 149           2  2019-01-01 00:35:40   2019-01-01 01:20:13                  N
# 185           2  2019-01-01 00:09:09   2019-01-01 01:04:26                  N
# ...         ...                  ...                   ...                ...
# 14666         1  2019-01-01 22:15:36   2019-01-01 22:28:07                  N
# 14753         1  2019-01-01 23:46:40   2019-01-01 23:53:04                  N
# 14830         2  2019-01-01 23:20:47   2019-01-01 23:28:04                  N
# 14959         2  2019-01-01 23:16:50   2019-01-01 23:24:38                  N
# 14970         2  2019-01-01 23:34:57   2019-01-01 23:45:51                  N
#
# ...

# %%
df6 = df.loc[df.PULocationID == 7]
df6.max()
# Out:
# VendorID                                   2
# lpep_pickup_datetime     2019-02-01 00:24:02
# lpep_dropoff_datetime    2019-02-01 00:28:09
# store_and_fwd_flag                         Y
# RatecodeID                                 5
# PULocationID                               7
# DOLocationID                             265
# passenger_count                            6
# trip_distance                          34.89
# fare_amount                            143.5
# extra                                    4.5
# mta_tax                                  0.5
# tip_amount                              88.0
# tolls_amount                            21.0
# ehail_fee                                NaN
# improvement_surcharge                    0.3
# total_amount                           144.8
# payment_type                               4
# trip_type                                  2
# congestion_surcharge                     0.0
# dtype: object

# %%
df6.loc[df6.tip_amount == 88.0]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 506162         2  2019-01-26 00:46:06   2019-01-26 00:50:10
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 506162                  N           1             7           146
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 506162                1           0.92          5.5    0.5      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 506162        88.0           0.0        NaN                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 506162          94.8             1          1                   NaN

# %%
df_zones.loc[df_zones.LocationID==146]
# Out:
#      LocationID Borough                           Zone service_zone
# 145         146  Queens  Long Island City/Queens Plaza    Boro Zone

# %%
df_zones.loc[df_zones.Zone == 'Astoria']
# Out:
#    LocationID Borough     Zone service_zone
# 6           7  Queens  Astoria    Boro Zone
