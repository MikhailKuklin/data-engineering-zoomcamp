# %%
import sys
# !conda install --yes --prefix {sys.prefix} psycopg2
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#df = pd.read_csv('green_tripdata_2019-01.csv', nrows=100)

# %%
#df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
#engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
#engine.connect()

# %%
#print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
#df.to_sql(name='green_data_taxi',con=engine, if_exists='append')
# Out:
# 100

# %%
#df_iter = pd.read_csv('green_tripdata_2019-01.csv', iterator=True, chunksize=100000)

# %%
#df = next(df_iter)

# %%
#len(df)
# Out:
# 100000

# %%
#df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
#df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4             2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-01-06 09:56:09   2019-01-06 10:01:30                  N
# 99996         2  2019-01-06 09:12:49   2019-01-06 09:52:38                  N
# 99997         2  2019-01-06 09:02:06   2019-01-06 09:37:42                  N
# 99998         2  2019-01-06 09:55:01   2019-01-06 10:04:34                  N
# 99999         2  2019-01-06 09:59:04   2019-01-06 10:24:33                  N
#
# ...

# %%
#df.head(n=0).to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
#%time df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 4.32 s, sys: 189 ms, total: 4.51 s
# Wall time: 9.43 s
# 1000

# %%
from time import time

# %%
df = pd.read_csv('green_tripdata_2019-01.csv', nrows=100)
df_iter = pd.read_csv('green_tripdata_2019-01.csv', iterator=True, chunksize=100000)
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

while True: 
    t_start = time()

    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk, took 10.662 second
# inserted another chunk, took 10.705 second
# inserted another chunk, took 10.436 second
# inserted another chunk, took 10.310 second
# inserted another chunk, took 10.263 second
# inserted another chunk, took 10.377 second
# inserted another chunk, took 3.334 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_3877/3636211601.py in <module>
#       6     t_start = time()
#       7
# ----> 8     df = next(df_iter)
#       9
#      10     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __next__(self)
#    1184     def __next__(self):
#    1185         try:
# -> 1186             return self.get_chunk()
#    1187         except StopIteration:
#    1188             self.close()
#
# ...

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2023-01-19 10:18:11--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.102.45, 52.216.61.224, 52.216.215.88, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.102.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi+_zone_lookup.csv.3’
#
# taxi+_zone_lookup.c 100%[===================>]  12.03K  --.-KB/s    in 0s
#
# 2023-01-19 10:18:11 (158 MB/s) - ‘taxi+_zone_lookup.csv.3’ saved [12322/12322]

# %%
df_zones = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265

# %% [markdown]
# # SQL commands were run with PostgreSQL

# %% [markdown]
# # Question 2. Understanding docker first run
#
# docker run -it --entrypoint=bash python:3.9

# %% [markdown]
# # Question 3. Count records

# %%
# Solution

#SELECT CAST(lpep_pickup_datetime as DATE) as "day", COUNT(trip_distance)
#  FROM green_taxi_data
#  WHERE (CAST(lpep_pickup_datetime as DATE) = '2019-01-15' AND CAST(lpep_dropoff_datetime as DATE) = '2019-01-15')
#  GROUP BY CAST(lpep_pickup_datetime AS DATE)

# %%
df = pd.read_csv('green_tripdata_2019-01.csv')

df.ltpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
# Out:
# /tmp/ipykernel_3877/2843409908.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.ltpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

# %%
df_task3 = df.loc[(df.lpep_pickup_datetime >'2019-01-15 00:00:00') & (df.lpep_pickup_datetime <'2019-01-16 00:00:00') & (df_task3.lpep_dropoff_datetime >'2019-01-15 00:00:00') & (df_task3.lpep_dropoff_datetime <'2019-01-16 00:00:00')]

df_task3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20530 entries, 272684 to 301517
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               20530 non-null  int64
#  1   lpep_pickup_datetime   20530 non-null  object
#  2   lpep_dropoff_datetime  20530 non-null  datetime64[ns]
#  3   store_and_fwd_flag     20530 non-null  object
#  4   RatecodeID             20530 non-null  int64
#  5   PULocationID           20530 non-null  int64
#  6   DOLocationID           20530 non-null  int64
#  7   passenger_count        20530 non-null  int64
#  8   trip_distance          20530 non-null  float64
#  9   fare_amount            20530 non-null  float64
#  10  extra                  20530 non-null  float64
#  11  mta_tax                20530 non-null  float64
#  12  tip_amount             20530 non-null  float64
#  13  tolls_amount           20530 non-null  float64
# ...

# %% [markdown]
# # Question 4. Largest trip for each day

# %%
### Solution

"""
SELECT CAST(lpep_pickup_datetime as DATE) as "day", MAX(trip_distance)
 FROM green_taxi_data
 WHERE CAST(lpep_pickup_datetime as DATE) IN ('2019-01-18','2019-01-28', '2019-01-15', '2019-01-10')
 GROUP BY CAST(lpep_pickup_datetime AS DATE)
 ORDER BY MAX(trip_distance) DESC
 LIMIT 1;
"""
# Out:
# '\nSELECT CAST(lpep_pickup_datetime as DATE) as "day", MAX(trip_distance)\n FROM green_taxi_data\n WHERE CAST(lpep_pickup_datetime as DATE) IN (\'2019-01-18\',\'2019-01-28\', \'2019-01-15\', \'2019-01-10\')\n GROUP BY CAST(lpep_pickup_datetime AS DATE)\n ORDER BY MAX(trip_distance) DESC\n LIMIT 1;\n'

# %%
df1 = df.loc[(df.lpep_pickup_datetime >'2019-01-28 00:00:00') & (df.lpep_pickup_datetime <'2019-01-29 00:00:00')]
df1['trip_distance'].max()

"""
SQL 

SELECT MAX(trip_distance)
 FROM green_taxi_data
 WHERE lpep_pickup_datetime > '2019-01-28 00:00:00' AND lpep_pickup_datetime < '2019-01-29 00:00:00';
"""
# Out:
# 64.27

# %%
df1 = df.loc[(df.lpep_pickup_datetime >'2019-01-15 00:00:00') & (df.lpep_pickup_datetime <'2019-01-16 00:00:00')]
df1['trip_distance'].max()

"""
SQL

SELECT MAX(trip_distance)
 FROM green_taxi_data
 WHERE lpep_pickup_datetime > '2019-01-15 00:00:00' AND lpep_pickup_datetime < '2019-01-16 00:00:00';
"""
# Out:
# 117.99

# %%
df1 = df.loc[(df.lpep_pickup_datetime >'2019-01-10 00:00:00') & (df.lpep_pickup_datetime <'2019-01-11 00:00:00')]
df1['trip_distance'].max()

"""
SQL

SELECT MAX(trip_distance)
 FROM green_taxi_data
 WHERE lpep_pickup_datetime > '2019-01-10 00:00:00' AND lpep_pickup_datetime < '2019-01-11 00:00:00';
"""
# Out:
# 64.2

# %% [markdown]
# # Question 5. The number of passengers

# %%
df_task5 = df.loc[(df.lpep_pickup_datetime >'2019-01-01 00:00:00') & (df.lpep_pickup_datetime <'2019-01-02 00:00:00')]

df_task5.loc[(df_task5['passenger_count']==2) ]

"""
SQL

SELECT CAST(lpep_pickup_datetime AS DATE) as "day", COUNT(1) FROM green_taxi_data t 
     WHERE passenger_count = 2
         AND CAST(lpep_pickup_datetime AS DATE) = '2019-01-01' 
     GROUP BY CAST(lpep_pickup_datetime AS DATE);
"""
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 11            2  2019-01-01 00:13:48   2019-01-01 00:21:00                  N
# 32            2  2019-01-01 00:40:23   2019-01-01 00:56:12                  N
# ...         ...                  ...                   ...                ...
# 14971         2  2019-01-01 23:33:40   2019-01-01 23:56:47                  N
# 14996         2  2019-01-01 23:10:16   2019-01-01 23:18:13                  N
# 14997         2  2019-01-01 23:34:15   2019-01-01 23:44:05                  N
# 15029         1  2019-01-01 23:08:14   2019-01-01 23:12:59                  N
# 15032         1  2019-01-01 23:42:48   2019-01-01 23:47:44                  N
#
# ...

# %%
df_task5.loc[(df_task5['passenger_count']==3) ]

"""
SQL

SELECT CAST(lpep_pickup_datetime AS DATE) as "day", COUNT(1) FROM green_taxi_data t 
    WHERE passenger_count = 3 
        AND CAST(lpep_pickup_datetime AS DATE) = '2019-01-01' 
    GROUP BY CAST(lpep_pickup_datetime AS DATE);
"""
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 31            2  2019-01-01 00:08:07   2019-01-01 00:18:36                  N
# 40            2  2019-01-01 00:31:28   2019-01-01 00:57:27                  N
# 67            2  2019-01-01 00:39:51   2019-01-01 00:43:05                  N
# 149           2  2019-01-01 00:35:40   2019-01-01 01:20:13                  N
# 185           2  2019-01-01 00:09:09   2019-01-01 01:04:26                  N
# ...         ...                  ...                   ...                ...
# 14666         1  2019-01-01 22:15:36   2019-01-01 22:28:07                  N
# 14753         1  2019-01-01 23:46:40   2019-01-01 23:53:04                  N
# 14830         2  2019-01-01 23:20:47   2019-01-01 23:28:04                  N
# 14959         2  2019-01-01 23:16:50   2019-01-01 23:24:38                  N
# 14970         2  2019-01-01 23:34:57   2019-01-01 23:45:51                  N
#
# ...

# %% [markdown]
# # Question 6. Largest tip

# %% [markdown]
# SQL solution (one query)
#
#      SELECT
#           lpep_pickup_datetime,
#           lpep_dropoff_datetime,
#           total_amount, tip_amount,
#           CONCAT(zpu."Zone") AS "pickup_loc",
#           CONCAT(zdo."Zone") AS "dropoff_loc"
#      FROM
#           green_taxi_data t,
#           zones zpu,
#           zones zdo
#      WHERE
#           t."PULocationID" = zpu."LocationID" AND
#           t."DOLocationID" = zdo."LocationID"
#      ) subquery
#      WHERE pickup_loc = 'Astoria'
#      GROUP BY dropoff_loc
#      ORDER BY MAX(tip_amount) DESC
#      LIMIT 1;

# %%
df_zones.loc[df_zones.Zone == 'Astoria']

"""
SQL

SELECT * FROM zones
 WHERE "Zone" = 'Astoria'
"""
# Out:
#    LocationID Borough     Zone service_zone
# 6           7  Queens  Astoria    Boro Zone

# %%
df6 = df.loc[df.PULocationID == 7]
df6.max()

"""
SQL

SELECT MAX(tip_amount) FROM green_taxi_data WHERE "PULocationID" = 7;
"""
# Out:
# VendorID                                   2
# lpep_pickup_datetime     2019-02-01 00:24:02
# lpep_dropoff_datetime    2019-02-01 00:28:09
# store_and_fwd_flag                         Y
# RatecodeID                                 5
# PULocationID                               7
# DOLocationID                             265
# passenger_count                            6
# trip_distance                          34.89
# fare_amount                            143.5
# extra                                    4.5
# mta_tax                                  0.5
# tip_amount                              88.0
# tolls_amount                            21.0
# ehail_fee                                NaN
# improvement_surcharge                    0.3
# total_amount                           144.8
# payment_type                               4
# trip_type                                  2
# congestion_surcharge                     0.0
# dtype: object

# %%
df6.loc[df6.tip_amount == 88.0]

"""
SQL

SELECT "DOLocationID" FROM green_taxi_data WHERE tip_amount = 88.0;
"""
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 506162         2  2019-01-26 00:46:06   2019-01-26 00:50:10
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 506162                  N           1             7           146
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 506162                1           0.92          5.5    0.5      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 506162        88.0           0.0        NaN                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 506162          94.8             1          1                   NaN

# %%
df_zones.loc[df_zones.LocationID==146]

"""
SQL

SELECT * FROM zones
  WHERE "LocationID" = 146
"""
# Out:
#      LocationID Borough                           Zone service_zone
# 145         146  Queens  Long Island City/Queens Plaza    Boro Zone
